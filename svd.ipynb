# %%
import pandas as pd
import numpy as np
from surprise import Dataset, Reader, SVD
from surprise.model_selection import train_test_split
from surprise.accuracy import rmse

# %%
# Load the data
events_df = pd.read_csv('./data/events.csv')

# %%
# Convert timestamps to datetime for better readability
events_df['timestamp'] = pd.to_datetime(events_df['timestamp'], unit='ms')

# %%
# Map event types to numeric values
event_type_mapping = {'view': 1, 'addtocart': 2, 'transaction': 3}
events_df['event'] = events_df['event'].map(event_type_mapping)

# %%
# Only sample 10,000 interactions
sampled_events_df = events_df.sample(n=100000, random_state=42)

# %%
# Define a split date (example: 80% of the data before the split date for training, 20% after for testing)
split_date = sampled_events_df['timestamp'].quantile(0.8)
print("Split date:", split_date)
# Out:
# Split date: 2015-08-18 15:23:50.822800128

# %%
# Split the data into training and testing sets based on the split date
train_df = sampled_events_df[sampled_events_df['timestamp'] < split_date]
test_df = sampled_events_df[sampled_events_df['timestamp'] >= split_date]

print("Number of interactions in the training set:", len(train_df))
print("Number of interactions in the test set:", len(test_df))
# Out:
# Number of interactions in the training set: 80000
# Number of interactions in the test set: 20000

# %%
# Prepare train set
train_user_item_matrix = train_df.set_index('timestamp') # sets the index
train_user_item_matrix = train_user_item_matrix.groupby(['visitorid']).count()
# Converts the index back to columns, making timestamp and visitorid regular columns again. (reset_index)
# Create a pivot table where rows are visitorid and columns are itemid, with the values being the count of event.
train_user_item_matrix = train_user_item_matrix.reset_index().pivot_table(index='visitorid', columns='itemid', values='event', fill_value=0)
# Create the user-item matrix with binary indicators
train_user_item_matrix = train_user_item_matrix.apply(lambda x: x.apply(lambda y: 1 if y > 0 else 0))

# %%
# Prepare test set
test_df = sampled_events_df[(sampled_events_df['timestamp'] >= split_date) & (sampled_events_df['visitorid'].isin(train_df['visitorid']))]
test_user_item_matrix = test_df.set_index('timestamp') # sets the index
test_user_item_matrix = test_user_item_matrix.groupby(['visitorid']).count()
test_user_item_matrix = test_user_item_matrix.reset_index().pivot_table(index='visitorid', columns='itemid', values='event', fill_value=0)
test_user_item_matrix = test_user_item_matrix.apply(lambda x: x.apply(lambda y: 1 if y > 0 else 0))

# %%
# Prepare the data for the SVD model
train_data = train_df[['visitorid', 'itemid', 'event']]
test_data = test_df[['visitorid', 'itemid', 'event']]

# %%
# Define the reader and load the data into the Surprise format
reader = Reader(rating_scale=(1, 3))

# %%
# Create the Dataset from the DataFrame
train_dataset = Dataset.load_from_df(train_data, reader)
test_dataset = Dataset.load_from_df(test_data, reader)

# %%
# Build the full trainset and testset
trainset = train_dataset.build_full_trainset()
testset = test_dataset.build_full_trainset().build_testset()

# %%
# Build the SVD model
svd = SVD()
# Train the model
svd.fit(trainset)

# %%
# Make predictions on the test set
predictions = svd.test(testset)

# %%
# Evaluate the model
print(f'Root Mean Squared Error: {rmse(predictions)}')
# Out:
# RMSE: 0.4177
# Root Mean Squared Error: 0.4177068827128145

# %%
# Function to obtain recommendations using SVD
def get_svd_recommendations(user_id, model, user_item_matrix, n_recommendations=5):
    if user_id not in user_item_matrix.index:
        return []
    all_items = user_item_matrix.columns
    rated_items = set(user_item_matrix.loc[user_id][user_item_matrix.loc[user_id] > 0].index)
    unrated_items = [item for item in all_items if item not in rated_items]
    
    # Predict the rating for all unrated items
    predictions = [model.predict(user_id, item) for item in unrated_items]
    
    # Sort the predictions by the highest estimated rating
    recommendations = sorted(predictions, key=lambda x: x.est, reverse=True)[:n_recommendations]
    
    recommended_items = [pred.iid for pred in recommendations]
    return recommended_items

# %%
# Evaluate the SVD model using hits, precision, and recall
def evaluate_svd_model(test_user_item_matrix, user_item_matrix, svd_model, k=5):
    hits = 0
    total_relevant = 0
    total_recommended = 0

    for user_id in test_user_item_matrix.index:
        if user_id in user_item_matrix.index:
            actual_items = set(test_user_item_matrix.loc[user_id][test_user_item_matrix.loc[user_id] > 0].index)
            recommended_items = set(get_svd_recommendations(user_id, svd_model, user_item_matrix, n_recommendations=k))
            hits += len(actual_items.intersection(recommended_items))
            total_relevant += len(actual_items)
            total_recommended += len(recommended_items)
            
            # Intermediate verification
            print(f'User ID: {user_id}')
            print(f'Actual items: {actual_items}')
            print(f'Recommended items: {recommended_items}')
            print(f'Intersection: {actual_items.intersection(recommended_items)}\n')

    precision = hits / total_recommended if total_recommended > 0 else 0
    recall = hits / total_relevant if total_relevant > 0 else 0

    return precision, recall, hits

# %%
# Calculate precision, recall, and number of hits
precision, recall, hits = evaluate_svd_model(test_user_item_matrix, train_user_item_matrix, svd, k=5)
# Out:
# User ID: 8043
# Actual items: {1}
# Recommended items: {32, 37, 6, 15, 16}
# Intersection: set()
#
# User ID: 8927
# Actual items: {1}
# Recommended items: {32, 37, 9, 15, 16}
# Intersection: set()
#
# User ID: 12356
# Actual items: {2}
# Recommended items: {2, 3, 37, 15, 16}
# Intersection: {2}
#
# User ID: 17676
# Actual items: {11}
# Recommended items: {32, 1, 2, 15, 16}
# Intersection: set()
#
# User ID: 18131
# Actual items: {1}
# Recommended items: {2, 3, 37, 6, 9}
# Intersection: set()
#
# User ID: 31174
# Actual items: {1}
# Recommended items: {1, 3, 4, 9, 16}
# Intersection: {1}
#
# User ID: 40140
# Actual items: {1}
# Recommended items: {32, 2, 3, 4, 6}
# Intersection: set()
#
# User ID: 42552
# Actual items: {1}
# Recommended items: {1, 2, 4, 6, 16}
# Intersection: {1}
#
# User ID: 43853
# Actual items: {1}
# Recommended items: {32, 37, 6, 9, 15}
# Intersection: set()
#
# User ID: 49302
# Actual items: {1}
# Recommended items: {2, 37, 9, 15, 16}
# Intersection: set()
#
# User ID: 54791
# Actual items: {2}
# Recommended items: {32, 1, 37, 15, 16}
# Intersection: set()
#
# User ID: 55997
# Actual items: {1}
# Recommended items: {32, 2, 3, 4, 5}
# Intersection: set()
#
# User ID: 60502
# Actual items: {1}
# Recommended items: {32, 2, 3, 4, 37}
# Intersection: set()
#
# User ID: 61715
# Actual items: {1}
# Recommended items: {2, 3, 9, 15, 16}
# Intersection: set()
#
# User ID: 61731
# Actual items: {1}
# Recommended items: {32, 37, 6, 15, 16}
# Intersection: set()
#
# User ID: 64931
# Actual items: {1}
# Recommended items: {32, 1, 9, 15, 16}
# Intersection: {1}
#
# User ID: 68318
# Actual items: {1}
# Recommended items: {32, 2, 3, 6, 9}
# Intersection: set()
#
# User ID: 70086
# Actual items: {1}
# Recommended items: {2, 37, 9, 15, 16}
# Intersection: set()
#
# User ID: 74388
# Actual items: {1}
# Recommended items: {2, 3, 6, 9, 15}
# Intersection: set()
#
# User ID: 79627
# Actual items: {35}
# Recommended items: {1, 2, 3, 37, 6}
# Intersection: set()
#
# User ID: 81232
# Actual items: {1}
# Recommended items: {2, 3, 4, 6, 9}
# Intersection: set()
#
# User ID: 82084
# Actual items: {1}
# Recommended items: {2, 3, 4, 5, 6}
# Intersection: set()
#
# User ID: 90729
# Actual items: {3}
# Recommended items: {2, 37, 6, 9, 16}
# Intersection: set()
#
# User ID: 90976
# Actual items: {1}
# Recommended items: {2, 3, 4, 5, 6}
# Intersection: set()
#
# User ID: 93627
# Actual items: {3}
# Recommended items: {32, 1, 2, 9, 15}
# Intersection: set()
#
# User ID: 104829
# Actual items: {1}
# Recommended items: {1, 2, 4, 37, 16}
# Intersection: {1}
#
# User ID: 106649
# Actual items: {1}
# Recommended items: {2, 3, 4, 6, 9}
# Intersection: set()
#
# User ID: 114362
# Actual items: {1}
# Recommended items: {1, 2, 37, 9, 16}
# Intersection: {1}
#
# User ID: 115677
# Actual items: {1}
# Recommended items: {32, 37, 6, 9, 15}
# Intersection: set()
#
# User ID: 130999
# Actual items: {2}
# Recommended items: {32, 1, 2, 37, 6}
# Intersection: {2}
#
# User ID: 136179
# Actual items: {1}
# Recommended items: {32, 2, 6, 9, 16}
# Intersection: set()
#
# User ID: 138041
# Actual items: {1}
# Recommended items: {2, 3, 4, 37, 15}
# Intersection: set()
#
# User ID: 140357
# Actual items: {1}
# Recommended items: {2, 3, 4, 9, 15}
# Intersection: set()
#
# User ID: 142991
# Actual items: {3}
# Recommended items: {32, 2, 3, 15, 16}
# Intersection: {3}
#
# User ID: 152693
# Actual items: {2}
# Recommended items: {1, 2, 3, 6, 16}
# Intersection: {2}
#
# User ID: 152963
# Actual items: {73}
# Recommended items: {32, 6, 9, 15, 16}
# Intersection: set()
#
# User ID: 155866
# Actual items: {2}
# Recommended items: {32, 37, 6, 9, 15}
# Intersection: set()
#
# User ID: 163049
# Actual items: {5}
# Recommended items: {32, 1, 2, 6, 15}
# Intersection: set()
#
# User ID: 167704
# Actual items: {1}
# Recommended items: {1, 2, 3, 9, 15}
# Intersection: {1}
#
# User ID: 173863
# Actual items: {22}
# Recommended items: {1, 2, 3, 37, 15}
# Intersection: set()
#
# User ID: 178024
# Actual items: {1}
# Recommended items: {32, 2, 3, 4, 15}
# Intersection: set()
#
# User ID: 178893
# Actual items: {2}
# Recommended items: {2, 3, 4, 5, 7}
# Intersection: {2}
#
# User ID: 182152
# Actual items: {3}
# Recommended items: {32, 2, 37, 6, 15}
# Intersection: set()
#
# User ID: 188814
# Actual items: {1}
# Recommended items: {32, 37, 6, 15, 16}
# Intersection: set()
#
# User ID: 191637
# Actual items: {2}
# Recommended items: {2, 37, 6, 9, 16}
# Intersection: {2}
#
# User ID: 194610
# Actual items: {1}
# Recommended items: {2, 3, 4, 5, 16}
# Intersection: set()
#
# User ID: 196109
# Actual items: {2}
# Recommended items: {2, 3, 37, 9, 16}
# Intersection: {2}
#
# User ID: 198153
# Actual items: {2}
# Recommended items: {1, 2, 3, 6, 9}
# Intersection: {2}
#
# User ID: 205325
# Actual items: {1}
# Recommended items: {32, 2, 3, 37, 15}
# Intersection: set()
#
# User ID: 208482
# Actual items: {1}
# Recommended items: {1, 3, 4, 5, 16}
# Intersection: {1}
#
# User ID: 216607
# Actual items: {1}
# Recommended items: {32, 2, 3, 4, 37}
# Intersection: set()
#
# User ID: 218828
# Actual items: {13}
# Recommended items: {1, 2, 3, 4, 37}
# Intersection: set()
#
# User ID: 221202
# Actual items: {1}
# Recommended items: {1, 2, 3, 4, 15}
# Intersection: {1}
#
# User ID: 227406
# Actual items: {1}
# Recommended items: {1, 3, 6, 15, 16}
# Intersection: {1}
#
# User ID: 228792
# Actual items: {1}
# Recommended items: {32, 2, 6, 9, 15}
# Intersection: set()
#
# User ID: 229157
# Actual items: {6}
# Recommended items: {1, 2, 3, 4, 16}
# Intersection: set()
#
# User ID: 234164
# Actual items: {1}
# Recommended items: {1, 2, 6, 15, 16}
# Intersection: {1}
#
# User ID: 234500
# Actual items: {1}
# Recommended items: {32, 2, 6, 9, 15}
# Intersection: set()
#
# User ID: 239473
# Actual items: {2}
# Recommended items: {32, 1, 3, 9, 15}
# Intersection: set()
#
# User ID: 244756
# Actual items: {10}
# Recommended items: {32, 1, 37, 15, 16}
# Intersection: set()
#
# User ID: 247235
# Actual items: {36}
# Recommended items: {32, 37, 9, 15, 16}
# Intersection: set()
#
# User ID: 252753
# Actual items: {1}
# Recommended items: {2, 3, 6, 9, 16}
# Intersection: set()
#
# User ID: 255589
# Actual items: {2}
# Recommended items: {32, 37, 6, 9, 16}
# Intersection: set()
#
# User ID: 258500
# Actual items: {1}
# Recommended items: {32, 1, 2, 4, 15}
# Intersection: {1}
#
# User ID: 265486
# Actual items: {1}
# Recommended items: {2, 3, 4, 5, 16}
# Intersection: set()
#
# User ID: 266417
# Actual items: {4}
# Recommended items: {2, 3, 37, 6, 16}
# Intersection: set()
#
# User ID: 274264
# Actual items: {1}
# Recommended items: {1, 37, 6, 15, 16}
# Intersection: {1}
#
# User ID: 276250
# Actual items: {1}
# Recommended items: {2, 3, 4, 5, 15}
# Intersection: set()
#
# User ID: 279801
# Actual items: {1}
# Recommended items: {32, 2, 37, 6, 9}
# Intersection: set()
#
# User ID: 281263
# Actual items: {1}
# Recommended items: {2, 3, 4, 5, 6}
# Intersection: set()
#
# User ID: 284741
# Actual items: {1}
# Recommended items: {32, 2, 3, 4, 6}
# Intersection: set()
#
# User ID: 290792
# Actual items: {1}
# Recommended items: {32, 37, 6, 9, 15}
# Intersection: set()
#
# User ID: 292229
# Actual items: {1}
# Recommended items: {32, 2, 37, 9, 15}
# Intersection: set()
#
# User ID: 295651
# Actual items: {1}
# Recommended items: {2, 3, 4, 5, 16}
# Intersection: set()
#
# User ID: 296431
# Actual items: {4}
# Recommended items: {2, 3, 9, 15, 16}
# Intersection: set()
#
# User ID: 300987
# Actual items: {1}
# Recommended items: {32, 2, 6, 9, 15}
# Intersection: set()
#
# User ID: 302631
# Actual items: {1}
# Recommended items: {2, 37, 6, 9, 16}
# Intersection: set()
#
# User ID: 303381
# Actual items: {16}
# Recommended items: {1, 37, 6, 15, 16}
# Intersection: {16}
#
# User ID: 310759
# Actual items: {10}
# Recommended items: {1, 2, 6, 9, 16}
# Intersection: set()
#
# User ID: 316600
# Actual items: {17}
# Recommended items: {1, 37, 6, 9, 16}
# Intersection: set()
#
# User ID: 316850
# Actual items: {10}
# Recommended items: {32, 1, 2, 6, 9}
# Intersection: set()
#
# User ID: 319048
# Actual items: {3}
# Recommended items: {32, 1, 2, 9, 15}
# Intersection: set()
#
# User ID: 321726
# Actual items: {1}
# Recommended items: {32, 2, 3, 4, 9}
# Intersection: set()
#
# User ID: 322384
# Actual items: {3}
# Recommended items: {1, 3, 6, 15, 16}
# Intersection: {3}
#
# User ID: 322513
# Actual items: {1}
# Recommended items: {1, 3, 4, 37, 15}
# Intersection: {1}
#
# User ID: 324319
# Actual items: {1}
# Recommended items: {32, 1, 3, 4, 15}
# Intersection: {1}
#
# User ID: 328629
# Actual items: {1}
# Recommended items: {2, 3, 4, 6, 16}
# Intersection: set()
#
# User ID: 331925
# Actual items: {2}
# Recommended items: {32, 1, 3, 4, 15}
# Intersection: set()
#
# User ID: 333168
# Actual items: {1}
# Recommended items: {2, 3, 37, 9, 16}
# Intersection: set()
#
# User ID: 334322
# Actual items: {1}
# Recommended items: {32, 2, 3, 37, 16}
# Intersection: set()
#
# User ID: 341275
# Actual items: {1}
# Recommended items: {32, 2, 37, 6, 9}
# Intersection: set()
#
# User ID: 342288
# Actual items: {1}
# Recommended items: {32, 2, 3, 4, 15}
# Intersection: set()
#
# User ID: 342436
# Actual items: {1}
# Recommended items: {32, 1, 37, 9, 15}
# Intersection: {1}
#
# User ID: 349459
# Actual items: {1}
# Recommended items: {2, 3, 4, 9, 16}
# Intersection: set()
#
# User ID: 352780
# Actual items: {1}
# Recommended items: {32, 2, 37, 9, 15}
# Intersection: set()
#
# User ID: 360419
# Actual items: {1}
# Recommended items: {2, 3, 37, 6, 16}
# Intersection: set()
#
# User ID: 361041
# Actual items: {8}
# Recommended items: {32, 1, 37, 9, 15}
# Intersection: set()
#
# User ID: 368609
# Actual items: {1}
# Recommended items: {2, 3, 6, 15, 16}
# Intersection: set()
#
# User ID: 373790
# Actual items: {1}
# Recommended items: {2, 3, 4, 6, 15}
# Intersection: set()
#
# User ID: 374363
# Actual items: {1}
# Recommended items: {32, 2, 6, 15, 16}
# Intersection: set()
#
# User ID: 375942
# Actual items: {1}
# Recommended items: {2, 37, 6, 15, 16}
# Intersection: set()
#
# User ID: 382824
# Actual items: {1}
# Recommended items: {2, 37, 6, 9, 15}
# Intersection: set()
#
# User ID: 384056
# Actual items: {1}
# Recommended items: {2, 3, 4, 37, 15}
# Intersection: set()
#
# User ID: 388200
# Actual items: {2}
# Recommended items: {32, 1, 2, 3, 37}
# Intersection: {2}
#
# User ID: 389799
# Actual items: {1}
# Recommended items: {32, 2, 37, 9, 15}
# Intersection: set()
#
# User ID: 391789
# Actual items: {1}
# Recommended items: {32, 2, 3, 37, 16}
# Intersection: set()
#
# User ID: 393300
# Actual items: {1}
# Recommended items: {1, 2, 4, 5, 16}
# Intersection: {1}
#
# User ID: 395573
# Actual items: {1}
# Recommended items: {32, 1, 2, 37, 15}
# Intersection: {1}
#
# User ID: 401423
# Actual items: {1}
# Recommended items: {2, 3, 6, 9, 15}
# Intersection: set()
#
# User ID: 403567
# Actual items: {3}
# Recommended items: {1, 2, 4, 6, 16}
# Intersection: set()
#
# User ID: 405457
# Actual items: {1}
# Recommended items: {2, 3, 4, 5, 7}
# Intersection: set()
#
# User ID: 408957
# Actual items: {1}
# Recommended items: {32, 2, 3, 6, 16}
# Intersection: set()
#
# User ID: 419841
# Actual items: {1}
# Recommended items: {1, 6, 9, 15, 16}
# Intersection: {1}
#
# User ID: 420080
# Actual items: {1}
# Recommended items: {32, 1, 2, 9, 15}
# Intersection: {1}
#
# User ID: 428220
# Actual items: {1}
# Recommended items: {32, 2, 37, 6, 16}
# Intersection: set()
#
# User ID: 432703
# Actual items: {1}
# Recommended items: {2, 3, 37, 15, 16}
# Intersection: set()
#
# User ID: 434207
# Actual items: {1}
# Recommended items: {2, 37, 9, 15, 16}
# Intersection: set()
#
# User ID: 435041
# Actual items: {1}
# Recommended items: {37, 6, 9, 15, 16}
# Intersection: set()
#
# User ID: 435571
# Actual items: {1}
# Recommended items: {2, 3, 4, 37, 6}
# Intersection: set()
#
# User ID: 455761
# Actual items: {1}
# Recommended items: {32, 2, 3, 4, 37}
# Intersection: set()
#
# User ID: 460925
# Actual items: {1}
# Recommended items: {32, 2, 6, 9, 16}
# Intersection: set()
#
# User ID: 466521
# Actual items: {1}
# Recommended items: {2, 3, 6, 15, 16}
# Intersection: set()
#
# User ID: 467732
# Actual items: {1}
# Recommended items: {2, 3, 4, 37, 16}
# Intersection: set()
#
# User ID: 468309
# Actual items: {1}
# Recommended items: {1, 2, 37, 15, 16}
# Intersection: {1}
#
# User ID: 468648
# Actual items: {1}
# Recommended items: {2, 3, 4, 6, 15}
# Intersection: set()
#
# User ID: 471010
# Actual items: {1}
# Recommended items: {32, 2, 3, 4, 5}
# Intersection: set()
#
# User ID: 475172
# Actual items: {2}
# Recommended items: {32, 1, 2, 37, 9}
# Intersection: {2}
#
# User ID: 481079
# Actual items: {1}
# Recommended items: {32, 2, 3, 37, 6}
# Intersection: set()
#
# User ID: 485689
# Actual items: {7}
# Recommended items: {32, 1, 2, 37, 6}
# Intersection: set()
#
# User ID: 488320
# Actual items: {1}
# Recommended items: {32, 1, 6, 15, 16}
# Intersection: {1}
#
# User ID: 491258
# Actual items: {1}
# Recommended items: {2, 3, 4, 5, 7}
# Intersection: set()
#
# User ID: 494469
# Actual items: {1}
# Recommended items: {32, 2, 37, 6, 15}
# Intersection: set()
#
# User ID: 494802
# Actual items: {1}
# Recommended items: {32, 37, 6, 9, 15}
# Intersection: set()
#
# User ID: 495016
# Actual items: {1}
# Recommended items: {32, 37, 6, 9, 15}
# Intersection: set()
#
# User ID: 502208
# Actual items: {3}
# Recommended items: {1, 37, 6, 9, 16}
# Intersection: set()
#
# User ID: 502832
# Actual items: {1}
# Recommended items: {32, 1, 37, 6, 15}
# Intersection: {1}
#
# User ID: 503614
# Actual items: {1}
# Recommended items: {2, 3, 4, 37, 16}
# Intersection: set()
#
# User ID: 506856
# Actual items: {1}
# Recommended items: {32, 1, 2, 6, 15}
# Intersection: {1}
#
# User ID: 507127
# Actual items: {1}
# Recommended items: {2, 3, 4, 5, 9}
# Intersection: set()
#
# User ID: 509017
# Actual items: {1}
# Recommended items: {32, 1, 3, 9, 15}
# Intersection: {1}
#
# User ID: 510651
# Actual items: {1}
# Recommended items: {32, 2, 3, 4, 5}
# Intersection: set()
#
# User ID: 511492
# Actual items: {2}
# Recommended items: {32, 2, 37, 9, 16}
# Intersection: {2}
#
# User ID: 516732
# Actual items: {1}
# Recommended items: {32, 2, 37, 9, 15}
# Intersection: set()
#
# User ID: 518659
# Actual items: {13}
# Recommended items: {32, 1, 2, 37, 9}
# Intersection: set()
#
# User ID: 522252
# Actual items: {1}
# Recommended items: {32, 2, 6, 9, 15}
# Intersection: set()
#
# User ID: 523337
# Actual items: {1}
# Recommended items: {2, 3, 37, 15, 16}
# Intersection: set()
#
# User ID: 530559
# Actual items: {32}
# Recommended items: {32, 37, 9, 15, 16}
# Intersection: {32}
#
# User ID: 533386
# Actual items: {1}
# Recommended items: {37, 6, 9, 15, 16}
# Intersection: set()
#
# User ID: 542164
# Actual items: {2}
# Recommended items: {2, 3, 4, 5, 6}
# Intersection: {2}
#
# User ID: 546086
# Actual items: {3}
# Recommended items: {32, 1, 2, 3, 37}
# Intersection: {3}
#
# User ID: 546498
# Actual items: {1}
# Recommended items: {32, 2, 3, 4, 37}
# Intersection: set()
#
# User ID: 550568
# Actual items: {1}
# Recommended items: {1, 2, 3, 6, 9}
# Intersection: {1}
#
# User ID: 551586
# Actual items: {1}
# Recommended items: {2, 3, 6, 9, 15}
# Intersection: set()
#
# User ID: 554137
# Actual items: {1}
# Recommended items: {2, 3, 37, 9, 16}
# Intersection: set()
#
# User ID: 557855
# Actual items: {1}
# Recommended items: {1, 3, 9, 15, 16}
# Intersection: {1}
#
# User ID: 558068
# Actual items: {1}
# Recommended items: {2, 3, 4, 5, 9}
# Intersection: set()
#
# User ID: 559179
# Actual items: {1}
# Recommended items: {32, 2, 3, 6, 9}
# Intersection: set()
#
# User ID: 560175
# Actual items: {1}
# Recommended items: {37, 6, 9, 15, 16}
# Intersection: set()
#
# User ID: 561675
# Actual items: {1}
# Recommended items: {2, 3, 37, 6, 15}
# Intersection: set()
#
# User ID: 563664
# Actual items: {1}
# Recommended items: {2, 3, 37, 6, 9}
# Intersection: set()
#
# User ID: 564199
# Actual items: {1}
# Recommended items: {32, 1, 2, 3, 4}
# Intersection: {1}
#
# User ID: 565492
# Actual items: {1}
# Recommended items: {32, 37, 9, 15, 16}
# Intersection: set()
#
# User ID: 565590
# Actual items: {1}
# Recommended items: {32, 2, 37, 9, 16}
# Intersection: set()
#
# User ID: 578878
# Actual items: {1}
# Recommended items: {2, 3, 6, 9, 16}
# Intersection: set()
#
# User ID: 581174
# Actual items: {3}
# Recommended items: {32, 2, 3, 6, 9}
# Intersection: {3}
#
# User ID: 583209
# Actual items: {1}
# Recommended items: {32, 2, 6, 9, 15}
# Intersection: set()
#
# User ID: 585209
# Actual items: {2}
# Recommended items: {32, 2, 3, 4, 16}
# Intersection: {2}
#
# User ID: 586367
# Actual items: {1}
# Recommended items: {32, 2, 6, 15, 16}
# Intersection: set()
#
# User ID: 587464
# Actual items: {1}
# Recommended items: {2, 3, 4, 5, 16}
# Intersection: set()
#
# User ID: 590239
# Actual items: {1}
# Recommended items: {32, 2, 3, 4, 6}
# Intersection: set()
#
# User ID: 595053
# Actual items: {1}
# Recommended items: {2, 3, 6, 15, 16}
# Intersection: set()
#
# User ID: 600934
# Actual items: {1}
# Recommended items: {37, 6, 9, 15, 16}
# Intersection: set()
#
# User ID: 601836
# Actual items: {2}
# Recommended items: {32, 1, 37, 15, 16}
# Intersection: set()
#
# User ID: 603581
# Actual items: {1}
# Recommended items: {32, 1, 6, 9, 15}
# Intersection: {1}
#
# User ID: 609318
# Actual items: {1}
# Recommended items: {32, 1, 2, 6, 15}
# Intersection: {1}
#
# User ID: 611222
# Actual items: {1}
# Recommended items: {1, 3, 6, 15, 16}
# Intersection: {1}
#
# User ID: 617101
# Actual items: {1}
# Recommended items: {32, 1, 37, 9, 15}
# Intersection: {1}
#
# User ID: 618697
# Actual items: {2}
# Recommended items: {32, 2, 37, 9, 15}
# Intersection: {2}
#
# User ID: 638482
# Actual items: {29}
# Recommended items: {32, 1, 2, 3, 15}
# Intersection: set()
#
# User ID: 638616
# Actual items: {1}
# Recommended items: {32, 1, 3, 4, 9}
# Intersection: {1}
#
# User ID: 638708
# Actual items: {1}
# Recommended items: {32, 2, 37, 9, 16}
# Intersection: set()
#
# User ID: 649511
# Actual items: {1}
# Recommended items: {32, 37, 6, 15, 16}
# Intersection: set()
#
# User ID: 651148
# Actual items: {1}
# Recommended items: {2, 3, 6, 15, 16}
# Intersection: set()
#
# User ID: 653755
# Actual items: {2}
# Recommended items: {32, 2, 3, 4, 5}
# Intersection: {2}
#
# User ID: 655159
# Actual items: {1}
# Recommended items: {2, 3, 37, 9, 16}
# Intersection: set()
#
# User ID: 670518
# Actual items: {1}
# Recommended items: {32, 1, 3, 4, 37}
# Intersection: {1}
#
# User ID: 683619
# Actual items: {1}
# Recommended items: {32, 2, 3, 6, 15}
# Intersection: set()
#
# User ID: 686800
# Actual items: {1}
# Recommended items: {1, 2, 9, 15, 16}
# Intersection: {1}
#
# User ID: 686854
# Actual items: {5}
# Recommended items: {32, 1, 2, 4, 15}
# Intersection: set()
#
# User ID: 687082
# Actual items: {1}
# Recommended items: {2, 3, 6, 9, 16}
# Intersection: set()
#
# User ID: 689912
# Actual items: {1}
# Recommended items: {32, 2, 3, 4, 9}
# Intersection: set()
#
# User ID: 692778
# Actual items: {1}
# Recommended items: {1, 2, 3, 4, 15}
# Intersection: {1}
#
# User ID: 693709
# Actual items: {3}
# Recommended items: {32, 1, 9, 15, 16}
# Intersection: set()
#
# User ID: 705106
# Actual items: {1}
# Recommended items: {32, 1, 3, 4, 9}
# Intersection: {1}
#
# User ID: 716395
# Actual items: {1}
# Recommended items: {2, 3, 4, 5, 16}
# Intersection: set()
#
# User ID: 722990
# Actual items: {1}
# Recommended items: {2, 37, 6, 15, 16}
# Intersection: set()
#
# User ID: 724541
# Actual items: {1}
# Recommended items: {32, 2, 3, 9, 15}
# Intersection: set()
#
# User ID: 729150
# Actual items: {1}
# Recommended items: {32, 2, 3, 6, 15}
# Intersection: set()
#
# User ID: 729978
# Actual items: {1}
# Recommended items: {32, 2, 3, 9, 16}
# Intersection: set()
#
# User ID: 734633
# Actual items: {1}
# Recommended items: {32, 1, 6, 15, 16}
# Intersection: {1}
#
# User ID: 739007
# Actual items: {1}
# Recommended items: {32, 2, 37, 6, 16}
# Intersection: set()
#
# User ID: 753008
# Actual items: {2}
# Recommended items: {32, 37, 6, 9, 16}
# Intersection: set()
#
# User ID: 754244
# Actual items: {2}
# Recommended items: {1, 37, 9, 15, 16}
# Intersection: set()
#
# User ID: 755706
# Actual items: {1}
# Recommended items: {32, 2, 37, 6, 9}
# Intersection: set()
#
# User ID: 760430
# Actual items: {2}
# Recommended items: {1, 3, 4, 6, 9}
# Intersection: set()
#
# User ID: 760450
# Actual items: {1}
# Recommended items: {2, 3, 37, 9, 15}
# Intersection: set()
#
# User ID: 762655
# Actual items: {2}
# Recommended items: {1, 2, 3, 37, 9}
# Intersection: {2}
#
# User ID: 763141
# Actual items: {4}
# Recommended items: {1, 2, 6, 15, 16}
# Intersection: set()
#
# User ID: 764259
# Actual items: {1}
# Recommended items: {2, 3, 4, 6, 15}
# Intersection: set()
#
# User ID: 766063
# Actual items: {1}
# Recommended items: {2, 3, 6, 9, 15}
# Intersection: set()
#
# User ID: 768334
# Actual items: {1}
# Recommended items: {32, 1, 2, 6, 9}
# Intersection: {1}
#
# User ID: 774486
# Actual items: {1}
# Recommended items: {2, 3, 4, 5, 9}
# Intersection: set()
#
# User ID: 783500
# Actual items: {1}
# Recommended items: {32, 2, 3, 9, 15}
# Intersection: set()
#
# User ID: 783557
# Actual items: {1}
# Recommended items: {1, 2, 37, 9, 15}
# Intersection: {1}
#
# User ID: 796178
# Actual items: {1}
# Recommended items: {32, 2, 37, 6, 9}
# Intersection: set()
#
# User ID: 798002
# Actual items: {11}
# Recommended items: {1, 2, 3, 4, 37}
# Intersection: set()
#
# User ID: 799331
# Actual items: {2}
# Recommended items: {32, 2, 3, 37, 6}
# Intersection: {2}
#
# User ID: 800654
# Actual items: {1}
# Recommended items: {32, 1, 3, 4, 37}
# Intersection: {1}
#
# User ID: 805200
# Actual items: {1}
# Recommended items: {1, 37, 6, 15, 16}
# Intersection: {1}
#
# User ID: 811745
# Actual items: {2}
# Recommended items: {32, 2, 3, 37, 16}
# Intersection: {2}
#
# User ID: 819698
# Actual items: {1}
# Recommended items: {32, 1, 37, 9, 16}
# Intersection: {1}
#
# User ID: 820805
# Actual items: {1}
# Recommended items: {32, 2, 3, 37, 9}
# Intersection: set()
#
# User ID: 824842
# Actual items: {2}
# Recommended items: {32, 1, 37, 9, 16}
# Intersection: set()
#
# User ID: 825321
# Actual items: {1}
# Recommended items: {1, 2, 6, 15, 16}
# Intersection: {1}
#
# User ID: 827075
# Actual items: {1}
# Recommended items: {2, 3, 37, 15, 16}
# Intersection: set()
#
# User ID: 837126
# Actual items: {1}
# Recommended items: {32, 2, 6, 9, 15}
# Intersection: set()
#
# User ID: 839424
# Actual items: {1}
# Recommended items: {2, 3, 4, 5, 7}
# Intersection: set()
#
# User ID: 840855
# Actual items: {1}
# Recommended items: {2, 3, 4, 9, 16}
# Intersection: set()
#
# User ID: 846767
# Actual items: {3}
# Recommended items: {32, 1, 3, 6, 9}
# Intersection: {3}
#
# User ID: 847682
# Actual items: {1}
# Recommended items: {1, 37, 6, 15, 16}
# Intersection: {1}
#
# User ID: 855614
# Actual items: {1}
# Recommended items: {1, 3, 4, 5, 9}
# Intersection: {1}
#
# User ID: 855660
# Actual items: {1}
# Recommended items: {32, 2, 3, 15, 16}
# Intersection: set()
#
# User ID: 856857
# Actual items: {1}
# Recommended items: {2, 3, 4, 37, 16}
# Intersection: set()
#
# User ID: 856874
# Actual items: {3}
# Recommended items: {1, 2, 3, 37, 16}
# Intersection: {3}
#
# User ID: 857013
# Actual items: {1}
# Recommended items: {2, 3, 4, 37, 16}
# Intersection: set()
#
# User ID: 861299
# Actual items: {5}
# Recommended items: {1, 2, 3, 4, 16}
# Intersection: set()
#
# User ID: 883745
# Actual items: {1}
# Recommended items: {1, 3, 37, 6, 16}
# Intersection: {1}
#
# User ID: 884965
# Actual items: {1}
# Recommended items: {2, 3, 37, 15, 16}
# Intersection: set()
#
# User ID: 890859
# Actual items: {1}
# Recommended items: {32, 2, 3, 4, 9}
# Intersection: set()
#
# User ID: 891076
# Actual items: {1}
# Recommended items: {1, 3, 9, 15, 16}
# Intersection: {1}
#
# User ID: 892013
# Actual items: {16}
# Recommended items: {32, 37, 6, 9, 16}
# Intersection: {16}
#
# User ID: 894555
# Actual items: {1}
# Recommended items: {2, 3, 4, 37, 6}
# Intersection: set()
#
# User ID: 894598
# Actual items: {1}
# Recommended items: {32, 2, 3, 15, 16}
# Intersection: set()
#
# User ID: 895999
# Actual items: {28}
# Recommended items: {1, 2, 9, 15, 16}
# Intersection: set()
#
# User ID: 896066
# Actual items: {3}
# Recommended items: {32, 1, 2, 15, 16}
# Intersection: set()
#
# User ID: 896347
# Actual items: {1}
# Recommended items: {32, 1, 3, 4, 16}
# Intersection: {1}
#
# User ID: 899857
# Actual items: {5}
# Recommended items: {32, 1, 2, 6, 9}
# Intersection: set()
#
# User ID: 901608
# Actual items: {3}
# Recommended items: {2, 3, 4, 9, 15}
# Intersection: {3}
#
# User ID: 901628
# Actual items: {1}
# Recommended items: {2, 3, 4, 37, 6}
# Intersection: set()
#
# User ID: 914082
# Actual items: {1}
# Recommended items: {2, 37, 9, 15, 16}
# Intersection: set()
#
# User ID: 914869
# Actual items: {1}
# Recommended items: {2, 6, 9, 15, 16}
# Intersection: set()
#
# User ID: 917791
# Actual items: {1}
# Recommended items: {32, 1, 37, 9, 15}
# Intersection: {1}
#
# User ID: 921225
# Actual items: {1}
# Recommended items: {1, 2, 3, 5, 7}
# Intersection: {1}
#
# User ID: 922323
# Actual items: {1}
# Recommended items: {32, 1, 3, 37, 9}
# Intersection: {1}
#
# User ID: 922417
# Actual items: {1}
# Recommended items: {32, 37, 6, 15, 16}
# Intersection: set()
#
# User ID: 928824
# Actual items: {1}
# Recommended items: {32, 37, 9, 15, 16}
# Intersection: set()
#
# User ID: 929638
# Actual items: {1}
# Recommended items: {1, 2, 3, 4, 6}
# Intersection: {1}
#
# User ID: 936023
# Actual items: {1}
# Recommended items: {32, 2, 3, 37, 9}
# Intersection: set()
#
# User ID: 939239
# Actual items: {2}
# Recommended items: {2, 3, 37, 6, 16}
# Intersection: {2}
#
# User ID: 944033
# Actual items: {1}
# Recommended items: {2, 3, 37, 15, 16}
# Intersection: set()
#
# User ID: 944550
# Actual items: {2}
# Recommended items: {32, 6, 9, 15, 16}
# Intersection: set()
#
# User ID: 944601
# Actual items: {1}
# Recommended items: {2, 3, 4, 15, 16}
# Intersection: set()
#
# User ID: 952700
# Actual items: {1}
# Recommended items: {32, 2, 3, 4, 37}
# Intersection: set()
#
# User ID: 952880
# Actual items: {1}
# Recommended items: {2, 37, 6, 15, 16}
# Intersection: set()
#
# User ID: 952974
# Actual items: {2}
# Recommended items: {1, 2, 3, 4, 15}
# Intersection: {2}
#
# User ID: 955587
# Actual items: {1}
# Recommended items: {1, 3, 4, 5, 7}
# Intersection: {1}
#
# User ID: 956186
# Actual items: {1}
# Recommended items: {32, 2, 3, 6, 9}
# Intersection: set()
#
# User ID: 959500
# Actual items: {1}
# Recommended items: {2, 3, 37, 6, 9}
# Intersection: set()
#
# User ID: 961612
# Actual items: {1}
# Recommended items: {2, 3, 4, 6, 16}
# Intersection: set()
#
# User ID: 962057
# Actual items: {1}
# Recommended items: {1, 2, 37, 15, 16}
# Intersection: {1}
#
# User ID: 962631
# Actual items: {1}
# Recommended items: {32, 1, 2, 37, 6}
# Intersection: {1}
#
# User ID: 962770
# Actual items: {3}
# Recommended items: {32, 6, 9, 15, 16}
# Intersection: set()
#
# User ID: 963348
# Actual items: {5}
# Recommended items: {1, 2, 3, 37, 16}
# Intersection: set()
#
# User ID: 965288
# Actual items: {1}
# Recommended items: {32, 2, 3, 6, 9}
# Intersection: set()
#
# User ID: 977753
# Actual items: {15}
# Recommended items: {32, 1, 3, 37, 9}
# Intersection: set()
#
# User ID: 981375
# Actual items: {5}
# Recommended items: {32, 2, 3, 4, 9}
# Intersection: set()
#
# User ID: 983143
# Actual items: {1}
# Recommended items: {1, 3, 4, 5, 9}
# Intersection: {1}
#
# User ID: 986980
# Actual items: {1}
# Recommended items: {32, 2, 6, 9, 16}
# Intersection: set()
#
# User ID: 990582
# Actual items: {1}
# Recommended items: {1, 37, 9, 15, 16}
# Intersection: {1}
#
# User ID: 999077
# Actual items: {1}
# Recommended items: {2, 3, 4, 6, 16}
# Intersection: set()
#
# User ID: 1000306
# Actual items: {2}
# Recommended items: {32, 1, 9, 15, 16}
# Intersection: set()
#
# User ID: 1003574
# Actual items: {1}
# Recommended items: {32, 37, 6, 9, 16}
# Intersection: set()
#
# User ID: 1013911
# Actual items: {1}
# Recommended items: {2, 3, 4, 37, 6}
# Intersection: set()
#
# User ID: 1015599
# Actual items: {2}
# Recommended items: {1, 2, 3, 4, 16}
# Intersection: {2}
#
# User ID: 1015928
# Actual items: {4}
# Recommended items: {1, 2, 3, 4, 37}
# Intersection: {4}
#
# User ID: 1017216
# Actual items: {2}
# Recommended items: {32, 1, 3, 37, 16}
# Intersection: set()
#
# User ID: 1019163
# Actual items: {1}
# Recommended items: {2, 3, 4, 5, 6}
# Intersection: set()
#
# User ID: 1024334
# Actual items: {11}
# Recommended items: {32, 1, 37, 9, 15}
# Intersection: set()
#
# User ID: 1030890
# Actual items: {1}
# Recommended items: {32, 2, 3, 4, 9}
# Intersection: set()
#
# User ID: 1031262
# Actual items: {1}
# Recommended items: {32, 2, 9, 15, 16}
# Intersection: set()
#
# User ID: 1032492
# Actual items: {1}
# Recommended items: {32, 37, 6, 9, 15}
# Intersection: set()
#
# User ID: 1035862
# Actual items: {3}
# Recommended items: {32, 2, 3, 6, 9}
# Intersection: {3}
#
# User ID: 1038623
# Actual items: {1}
# Recommended items: {1, 3, 6, 9, 16}
# Intersection: {1}
#
# User ID: 1038991
# Actual items: {1}
# Recommended items: {2, 3, 37, 15, 16}
# Intersection: set()
#
# User ID: 1043513
# Actual items: {1}
# Recommended items: {32, 2, 37, 6, 15}
# Intersection: set()
#
# User ID: 1045665
# Actual items: {1}
# Recommended items: {32, 2, 3, 37, 16}
# Intersection: set()
#
# User ID: 1046904
# Actual items: {1}
# Recommended items: {2, 3, 37, 6, 16}
# Intersection: set()
#
# User ID: 1050032
# Actual items: {1}
# Recommended items: {37, 6, 9, 15, 16}
# Intersection: set()
#
# User ID: 1053149
# Actual items: {1}
# Recommended items: {2, 3, 37, 6, 9}
# Intersection: set()
#
# User ID: 1058714
# Actual items: {1}
# Recommended items: {2, 3, 4, 37, 6}
# Intersection: set()
#
# User ID: 1059446
# Actual items: {1}
# Recommended items: {32, 2, 3, 6, 9}
# Intersection: set()
#
# User ID: 1076366
# Actual items: {2}
# Recommended items: {1, 3, 4, 37, 9}
# Intersection: set()
#
# User ID: 1076842
# Actual items: {1}
# Recommended items: {32, 1, 37, 15, 16}
# Intersection: {1}
#
# User ID: 1081664
# Actual items: {3}
# Recommended items: {1, 2, 37, 6, 15}
# Intersection: set()
#
# User ID: 1083118
# Actual items: {1}
# Recommended items: {32, 1, 37, 6, 9}
# Intersection: {1}
#
# User ID: 1083704
# Actual items: {1}
# Recommended items: {32, 2, 3, 37, 16}
# Intersection: set()
#
# User ID: 1090460
# Actual items: {1}
# Recommended items: {32, 1, 2, 3, 37}
# Intersection: {1}
#
# User ID: 1090887
# Actual items: {1}
# Recommended items: {32, 2, 37, 6, 15}
# Intersection: set()
#
# User ID: 1094964
# Actual items: {2}
# Recommended items: {1, 2, 3, 6, 16}
# Intersection: {2}
#
# User ID: 1096666
# Actual items: {1}
# Recommended items: {1, 3, 4, 5, 16}
# Intersection: {1}
#
# User ID: 1098890
# Actual items: {2}
# Recommended items: {32, 37, 6, 9, 15}
# Intersection: set()
#
# User ID: 1102098
# Actual items: {1}
# Recommended items: {32, 1, 3, 4, 9}
# Intersection: {1}
#
# User ID: 1103829
# Actual items: {1}
# Recommended items: {32, 2, 3, 4, 5}
# Intersection: set()
#
# User ID: 1104227
# Actual items: {1}
# Recommended items: {37, 6, 9, 15, 16}
# Intersection: set()
#
# User ID: 1116235
# Actual items: {1}
# Recommended items: {32, 2, 3, 9, 16}
# Intersection: set()
#
# User ID: 1116522
# Actual items: {1}
# Recommended items: {32, 2, 3, 4, 37}
# Intersection: set()
#
# User ID: 1116566
# Actual items: {1}
# Recommended items: {32, 1, 6, 15, 16}
# Intersection: {1}
#
# User ID: 1118731
# Actual items: {1}
# Recommended items: {32, 2, 3, 9, 16}
# Intersection: set()
#
# User ID: 1119917
# Actual items: {3}
# Recommended items: {32, 1, 6, 9, 15}
# Intersection: set()
#
# User ID: 1121108
# Actual items: {1}
# Recommended items: {2, 3, 37, 6, 9}
# Intersection: set()
#
# User ID: 1122231
# Actual items: {1}
# Recommended items: {1, 2, 3, 15, 16}
# Intersection: {1}
#
# User ID: 1126569
# Actual items: {16}
# Recommended items: {1, 2, 3, 37, 6}
# Intersection: set()
#
# User ID: 1127065
# Actual items: {2}
# Recommended items: {32, 37, 6, 9, 16}
# Intersection: set()
#
# User ID: 1128663
# Actual items: {1}
# Recommended items: {1, 3, 6, 9, 15}
# Intersection: {1}
#
# User ID: 1130159
# Actual items: {1}
# Recommended items: {2, 3, 37, 15, 16}
# Intersection: set()
#
# User ID: 1131650
# Actual items: {1}
# Recommended items: {2, 3, 37, 15, 16}
# Intersection: set()
#
# User ID: 1133112
# Actual items: {2}
# Recommended items: {2, 3, 37, 6, 15}
# Intersection: {2}
#
# User ID: 1140886
# Actual items: {1}
# Recommended items: {1, 2, 3, 15, 16}
# Intersection: {1}
#
# User ID: 1143105
# Actual items: {1}
# Recommended items: {32, 2, 37, 9, 15}
# Intersection: set()
#
# User ID: 1144130
# Actual items: {1}
# Recommended items: {32, 1, 2, 37, 6}
# Intersection: {1}
#
# User ID: 1147655
# Actual items: {1}
# Recommended items: {2, 3, 4, 5, 16}
# Intersection: set()
#
# User ID: 1147663
# Actual items: {1}
# Recommended items: {32, 2, 3, 6, 9}
# Intersection: set()
#
# User ID: 1148072
# Actual items: {1}
# Recommended items: {32, 37, 6, 9, 15}
# Intersection: set()
#
# User ID: 1150086
# Actual items: {45}
# Recommended items: {32, 1, 9, 15, 16}
# Intersection: set()
#
# User ID: 1150128
# Actual items: {1}
# Recommended items: {32, 2, 3, 37, 15}
# Intersection: set()
#
# User ID: 1165148
# Actual items: {15}
# Recommended items: {1, 2, 3, 37, 6}
# Intersection: set()
#
# User ID: 1165349
# Actual items: {1}
# Recommended items: {32, 6, 9, 15, 16}
# Intersection: set()
#
# User ID: 1166728
# Actual items: {1}
# Recommended items: {2, 3, 4, 6, 16}
# Intersection: set()
#
# User ID: 1170710
# Actual items: {1}
# Recommended items: {2, 3, 4, 5, 6}
# Intersection: set()
#
# User ID: 1172198
# Actual items: {1}
# Recommended items: {32, 1, 2, 9, 15}
# Intersection: {1}
#
# User ID: 1173155
# Actual items: {1}
# Recommended items: {2, 3, 4, 5, 16}
# Intersection: set()
#
# User ID: 1186261
# Actual items: {1}
# Recommended items: {2, 3, 9, 15, 16}
# Intersection: set()
#
# User ID: 1187998
# Actual items: {3}
# Recommended items: {1, 3, 4, 9, 15}
# Intersection: {3}
#
# User ID: 1188952
# Actual items: {2}
# Recommended items: {1, 2, 37, 6, 16}
# Intersection: {2}
#
# User ID: 1193756
# Actual items: {1}
# Recommended items: {32, 1, 3, 15, 16}
# Intersection: {1}
#
# User ID: 1202167
# Actual items: {1}
# Recommended items: {2, 3, 37, 6, 16}
# Intersection: set()
#
# User ID: 1205716
# Actual items: {1}
# Recommended items: {2, 3, 4, 37, 15}
# Intersection: set()
#
# User ID: 1217245
# Actual items: {1}
# Recommended items: {32, 2, 3, 9, 16}
# Intersection: set()
#
# User ID: 1218580
# Actual items: {1}
# Recommended items: {32, 2, 3, 9, 15}
# Intersection: set()
#
# User ID: 1220253
# Actual items: {1}
# Recommended items: {32, 2, 3, 6, 9}
# Intersection: set()
#
# User ID: 1222911
# Actual items: {1}
# Recommended items: {32, 37, 6, 15, 16}
# Intersection: set()
#
# User ID: 1228860
# Actual items: {1}
# Recommended items: {2, 37, 6, 9, 16}
# Intersection: set()
#
# User ID: 1243200
# Actual items: {1}
# Recommended items: {2, 3, 4, 6, 15}
# Intersection: set()
#
# User ID: 1244339
# Actual items: {1}
# Recommended items: {2, 3, 6, 9, 16}
# Intersection: set()
#
# User ID: 1245758
# Actual items: {1}
# Recommended items: {2, 3, 9, 15, 16}
# Intersection: set()
#
# User ID: 1246166
# Actual items: {1}
# Recommended items: {32, 37, 6, 9, 15}
# Intersection: set()
#
# User ID: 1247528
# Actual items: {1}
# Recommended items: {2, 3, 37, 6, 9}
# Intersection: set()
#
# User ID: 1247698
# Actual items: {1}
# Recommended items: {32, 2, 3, 4, 5}
# Intersection: set()
#
# User ID: 1248016
# Actual items: {2}
# Recommended items: {2, 3, 4, 5, 9}
# Intersection: {2}
#
# User ID: 1248854
# Actual items: {1}
# Recommended items: {1, 2, 6, 15, 16}
# Intersection: {1}
#
# User ID: 1254737
# Actual items: {1}
# Recommended items: {32, 1, 37, 9, 15}
# Intersection: {1}
#
# User ID: 1254881
# Actual items: {1}
# Recommended items: {32, 37, 6, 9, 15}
# Intersection: set()
#
# User ID: 1261067
# Actual items: {5}
# Recommended items: {32, 2, 37, 6, 15}
# Intersection: set()
#
# User ID: 1266227
# Actual items: {2}
# Recommended items: {1, 3, 4, 37, 6}
# Intersection: set()
#
# User ID: 1269359
# Actual items: {1}
# Recommended items: {2, 3, 4, 37, 6}
# Intersection: set()
#
# User ID: 1270042
# Actual items: {1}
# Recommended items: {32, 6, 9, 15, 16}
# Intersection: set()
#
# User ID: 1270138
# Actual items: {1}
# Recommended items: {32, 2, 37, 6, 9}
# Intersection: set()
#
# User ID: 1274320
# Actual items: {1}
# Recommended items: {2, 3, 4, 6, 15}
# Intersection: set()
#
# User ID: 1274497
# Actual items: {1}
# Recommended items: {32, 6, 9, 15, 16}
# Intersection: set()
#
# User ID: 1282452
# Actual items: {3}
# Recommended items: {32, 37, 9, 15, 16}
# Intersection: set()
#
# User ID: 1292316
# Actual items: {1}
# Recommended items: {1, 3, 6, 15, 16}
# Intersection: {1}
#
# User ID: 1295811
# Actual items: {1}
# Recommended items: {32, 2, 3, 4, 15}
# Intersection: set()
#
# User ID: 1300007
# Actual items: {1}
# Recommended items: {32, 2, 37, 6, 15}
# Intersection: set()
#
# User ID: 1300656
# Actual items: {1}
# Recommended items: {1, 2, 4, 9, 15}
# Intersection: {1}
#
# User ID: 1300989
# Actual items: {1}
# Recommended items: {32, 2, 3, 4, 9}
# Intersection: set()
#
# User ID: 1302486
# Actual items: {1}
# Recommended items: {2, 3, 4, 6, 15}
# Intersection: set()
#
# User ID: 1310041
# Actual items: {1}
# Recommended items: {32, 2, 3, 4, 16}
# Intersection: set()
#
# User ID: 1312271
# Actual items: {1}
# Recommended items: {32, 1, 3, 37, 15}
# Intersection: {1}
#
# User ID: 1313381
# Actual items: {1}
# Recommended items: {37, 6, 9, 15, 16}
# Intersection: set()
#
# User ID: 1313498
# Actual items: {1}
# Recommended items: {32, 1, 37, 6, 15}
# Intersection: {1}
#
# User ID: 1313518
# Actual items: {1}
# Recommended items: {32, 6, 9, 15, 16}
# Intersection: set()
#
# User ID: 1314185
# Actual items: {1}
# Recommended items: {32, 2, 6, 9, 15}
# Intersection: set()
#
# User ID: 1315473
# Actual items: {1}
# Recommended items: {2, 3, 4, 6, 15}
# Intersection: set()
#
# User ID: 1325269
# Actual items: {1}
# Recommended items: {32, 1, 37, 6, 15}
# Intersection: {1}
#
# User ID: 1326989
# Actual items: {1}
# Recommended items: {1, 2, 4, 37, 6}
# Intersection: {1}
#
# User ID: 1327144
# Actual items: {3}
# Recommended items: {32, 1, 9, 15, 16}
# Intersection: set()
#
# User ID: 1327628
# Actual items: {1}
# Recommended items: {32, 2, 6, 9, 15}
# Intersection: set()
#
# User ID: 1330764
# Actual items: {1}
# Recommended items: {1, 37, 6, 9, 16}
# Intersection: {1}
#
# User ID: 1331304
# Actual items: {2}
# Recommended items: {1, 3, 4, 9, 16}
# Intersection: set()
#
# User ID: 1332095
# Actual items: {4}
# Recommended items: {32, 1, 2, 37, 9}
# Intersection: set()
#
# User ID: 1336078
# Actual items: {1}
# Recommended items: {32, 2, 3, 4, 5}
# Intersection: set()
#
# User ID: 1336835
# Actual items: {4}
# Recommended items: {32, 1, 9, 15, 16}
# Intersection: set()
#
# User ID: 1342601
# Actual items: {1}
# Recommended items: {2, 3, 4, 5, 16}
# Intersection: set()
#
# User ID: 1347019
# Actual items: {1}
# Recommended items: {32, 1, 2, 37, 9}
# Intersection: {1}
#
# User ID: 1348163
# Actual items: {1}
# Recommended items: {1, 2, 37, 15, 16}
# Intersection: {1}
#
# User ID: 1352044
# Actual items: {3}
# Recommended items: {32, 1, 3, 4, 9}
# Intersection: {3}
#
# User ID: 1352527
# Actual items: {1}
# Recommended items: {2, 3, 4, 5, 6}
# Intersection: set()
#
# User ID: 1355799
# Actual items: {1}
# Recommended items: {1, 3, 4, 5, 16}
# Intersection: {1}
#
# User ID: 1357083
# Actual items: {1}
# Recommended items: {2, 3, 37, 15, 16}
# Intersection: set()
#
# User ID: 1358298
# Actual items: {1}
# Recommended items: {32, 2, 37, 6, 15}
# Intersection: set()
#
# User ID: 1359187
# Actual items: {1}
# Recommended items: {32, 6, 9, 15, 16}
# Intersection: set()
#
# User ID: 1360073
# Actual items: {1}
# Recommended items: {32, 2, 3, 4, 16}
# Intersection: set()
#
# User ID: 1361818
# Actual items: {1}
# Recommended items: {2, 3, 4, 9, 15}
# Intersection: set()
#
# User ID: 1363207
# Actual items: {1}
# Recommended items: {2, 3, 4, 37, 6}
# Intersection: set()
#
# User ID: 1369328
# Actual items: {2}
# Recommended items: {1, 3, 4, 5, 7}
# Intersection: set()
#
# User ID: 1369915
# Actual items: {1}
# Recommended items: {32, 2, 37, 6, 16}
# Intersection: set()
#
# User ID: 1375467
# Actual items: {1}
# Recommended items: {32, 2, 37, 9, 16}
# Intersection: set()
#
# User ID: 1378144
# Actual items: {1}
# Recommended items: {32, 2, 3, 37, 9}
# Intersection: set()
#
# User ID: 1378697
# Actual items: {2}
# Recommended items: {32, 1, 3, 37, 15}
# Intersection: set()
#
# User ID: 1379388
# Actual items: {1}
# Recommended items: {32, 2, 37, 15, 16}
# Intersection: set()
#
# User ID: 1386841
# Actual items: {1}
# Recommended items: {2, 3, 4, 15, 16}
# Intersection: set()
#
# User ID: 1403769
# Actual items: {2}
# Recommended items: {1, 2, 37, 6, 15}
# Intersection: {2}
#
# User ID: 1407169
# Actual items: {1}
# Recommended items: {2, 3, 4, 5, 6}
# Intersection: set()
#
# Precision@5: 0.0585956416464891
# Recall@5: 0.2929782082324455
# Hits@5: 121

# %%
print(f'Precision@5: {precision}')
print(f'Recall@5: {recall}')
print(f'Hits@5: {hits}')
# Out:
# Precision@5: 0.0585956416464891
# Recall@5: 0.2929782082324455
# Hits@5: 121
